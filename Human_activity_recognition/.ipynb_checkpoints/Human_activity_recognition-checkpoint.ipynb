# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mediapipe as mp
import os
import cv2
import time

# %%
mp_drawing=mp.solutions.drawing_utils
mp_holistic=mp.solutions.holistic

# %% [markdown]
# 1. Face = 468
# 2. Pose = 33
# 3. Hand = 21 per hand

# %%
def mp_detection(frame,holistic):
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB) 
    
    image.flags.writeable = False                     # Image is no longer writeable
    results = holistic.process(image)                 
    image.flags.writeable = True                      # Image is now writeable 
    
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) 
    return image, results

# %%
def draw_landmarks(image, results):
    
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 

    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 

    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
cap.set(3,1000)
cap.set(4,1000)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        success, frame = cap.read()
        
        # Holistic points detection
        image, results = mp_detection(frame, holistic)
        
        # Draw landmarks on the image
        draw_landmarks(image, results)

        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
draw_landmarks(frame,results)
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))

# %% [markdown]
# - Picture of last frame with landmarks on it. <br>
# - Only Pose landmarks are stored as zero when there is no pose, others are not stored. So it should be taken care.<br>
# For ex : In the above image there is no left hand so values are not stored. To solve this assign those values to zero.

# %% [markdown]
# ### Keypoint Values

# %%
# Storing landmarks positions in respective arrays

def extract_keypoints(results):
    pose = np.array([[i.x, i.y, i.z, i.visibility] for i in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[i.x, i.y, i.z] for i in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[i.x, i.y, i.z] for i in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[i.x, i.y, i.z] for i in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# ### Creating folders

# %%
# path for main data folder
path=os.path.join('HAR_Data')

# action sub folder name
actions=np.array(['1','2','3'])

# Number of video per action folder
no_of_videos=30

# no of frames per video to be taken for training
no_of_frames=30

# %%
for action in actions: 
    for i in range(1,no_of_videos+1): # 1 to 30 folders named accordingly
        try: 
            os.makedirs(os.path.join(path, action, str(i)))  # making directory with path, folder,sub folder
        except:
            pass

# %% [markdown]
# ### Collecting Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
cap.set(3,1000)
cap.set(4,1000)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    for action in actions:
        
        for vid in range(1,no_of_videos+1):
            
            for nf in range(1,no_of_frames+1):

                ret, frame = cap.read()

                image, results = mp_detection(frame, holistic)

                draw_landmarks(image, results)
                
                # wait logic
                if nf == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 1, cv2.LINE_AA)
                    
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, vid), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(1000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, vid), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    
                    cv2.imshow('OpenCV Feed', image)
                
                # Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(path, action, str(vid), str(nf))
                np.save(npy_path, keypoints)
                
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
videos, labels = [], []
for action in actions:
    for vid in np.array(os.listdir(os.path.join(path, action))).astype(int):
        window = []
        for frame_num in range(1,no_of_frames+1):
            res = np.load(os.path.join(path, action, str(vid), "{}.npy".format(frame_num)))
            window.append(res)
        videos.append(window)
        labels.append(label_map[action])

# %%
x = np.array(videos)
y = to_categorical(labels).astype(int)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.05)

# %%
x.shape,y.shape
# Out:
# ((90, 30, 1662), (90, 3))

# %% [markdown]
# ### Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import Dropout

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(30,1662)))
model.add(Dropout(0.5))
model.add(Dense(100, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100)               705200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 100)               10100
#
#  dense_1 (Dense)             (None, 3)                 303
#
# ...
# Total params: 715,603
# Trainable params: 715,603
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(x_train, y_train, epochs=300, callbacks=[tb_callback])
# Out:
# Epoch 1/300
# 3/3 [==============================] - 3s 74ms/step - loss: 1.1384 - categorical_accuracy: 0.3882
# Epoch 2/300
# 3/3 [==============================] - 0s 79ms/step - loss: 1.2412 - categorical_accuracy: 0.2706
# Epoch 3/300
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0815 - categorical_accuracy: 0.3529
# Epoch 4/300
# 3/3 [==============================] - 0s 78ms/step - loss: 1.1431 - categorical_accuracy: 0.3176
# Epoch 5/300
# 3/3 [==============================] - 0s 80ms/step - loss: 1.1648 - categorical_accuracy: 0.2588
# Epoch 6/300
# 3/3 [==============================] - 0s 74ms/step - loss: 1.1132 - categorical_accuracy: 0.3765
# Epoch 7/300
# 3/3 [==============================] - 0s 74ms/step - loss: 1.1053 - categorical_accuracy: 0.3765
# Epoch 8/300
# 3/3 [==============================] - 0s 77ms/step - loss: 1.1451 - categorical_accuracy: 0.3294
# Epoch 9/300
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-a3051ac3fac8e757" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a3051ac3fac8e757");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Make Predictions

# %%
res = model.predict(x_test)
actions[np.argmax(res[4])],actions[np.argmax(y_test[4])]
# Out:
# ('1', '1')

# %%
model.save('action.h5')

# %%
model.load_weights('action.h5')

# %% [markdown]
# ### Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(x_test)

ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat), accuracy_score(ytrue, yhat)
# Out:
# (array([[[3, 1],
#          [0, 1]],
#
#         [[3, 0],
#          [2, 0]],
#
#         [[2, 1],
#          [0, 2]]], dtype=int64),
#  0.6)

# %% [markdown]
# ### Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
cap.set(3,1000)
cap.set(4,1000)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        ret, frame = cap.read()


        image, results = mp_detection(frame, holistic)
        
        draw_landmarks(image, results)
        
        # Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            predictions.append(np.argmax(res))
            
            
        # Visualization logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Visulaization probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()
